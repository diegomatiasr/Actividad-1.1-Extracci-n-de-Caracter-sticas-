# %% [markdown]
# ## Actividad 1.1

# %% [markdown]
# **Diego Matias Rossano | A01737509**

# %%
#Instalamos librería para análisis de variables categóricas
# %pip install funpymodeling
# Out:
# ...
#
# [notice] A new release of pip is available: 24.0 -> 25.0.1
# [notice] To update, run: pip3.12 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
#Importamos las librerias pandas, numpy y matplotlib respectivamente
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from funpymodeling.exploratory import freq_tbl

# %%
# %pip install openpyxl
# Out:
# ...
#
# [notice] A new release of pip is available: 24.0 -> 25.0.1
# [notice] To update, run: pip3.12 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# Carga desde un archivo .csv sin índice
data = pd.read_csv("Sicily.csv")
data.head(5)
# Out:
#    Unnamed: 0                                               name  \
# 0           0               SEASIDE - Historic Antique Residence
# 1           1  BnB center near station with balcony and break...
# 2           2                         Etna-sea a panoramic villa
# 3           3                             Two steps from the sea
# 4           4                                    Villa Verdemare
#
#                                          description  \
# 0  WINEYARD WITH COLOURS OF THE SEASIDE.<br /><br...
# 1  Near the Central Station and the beginning of ...
# 2  Our country house, swathed in the greenery of ...
# 3  Very nice flat in front of the beach with a wo...
# 4  Wonderful villa that can easily accommodate up...
#
#                                neighborhood_overview     host_name host_since  \
# 0                                                NaN  Yumi Adriano   13/05/09
# 1  The neighborhood is in a residential area, cen...      Giuseppe   05/03/10
# ...

# %%
# Identificar valores nulos por columna

valores_nulos = data.isnull().sum()
valores_nulos
# Out:
# Unnamed: 0                                         0
# name                                               0
# description                                     1791
# neighborhood_overview                          31725
# host_name                                          3
# host_since                                         3
# host_location                                  19123
# host_about                                     35860
# host_response_time                             21959
# host_response_rate                             21959
# host_acceptance_rate                           10493
# host_is_superhost                               1062
# host_listings_count                                3
# host_total_listings_count                          3
# host_has_profile_pic                               3
# host_identity_verified                             3
# neighbourhood                                  31724
# latitude                                           0
# ...

# %%
# Eliminar filas con nulos
# No se agrega nada para eliminar filas y 1 para eliminar columnas
data1 = data.dropna()
data1
# Out:
#        Unnamed: 0                                               name  \
# 1               1  BnB center near station with balcony and break...
# 2               2                         Etna-sea a panoramic villa
# 5               5                   Penthouse Cordari Ortigia Island
# 10             10  B&B Bianco e Blu - in the centre - 50m by the sea
# 16             16                        Vecchia Girgenti Short Lets
# ...           ...                                                ...
# 55362       55362  Relax and Comfort in a welcoming home in Catania.
# 55486       55486         SUN VITO - Casa Vacanze vicino la Spiaggia
# 55645       55645                                Eleven Luxury Suite
# 55666       55666  Marina Home - luxury appartament - centro storico
# 55817       55817                             La Giostra del Massimo
#
#                                              description  \
# 1      Near the Central Station and the beginning of ...
# ...

# %%
# Identificar valores nulos por columna

valores_nulos = data1.isnull().sum()
valores_nulos
# Out:
# Unnamed: 0                                     0
# name                                           0
# description                                    0
# neighborhood_overview                          0
# host_name                                      0
# host_since                                     0
# host_location                                  0
# host_about                                     0
# host_response_time                             0
# host_response_rate                             0
# host_acceptance_rate                           0
# host_is_superhost                              0
# host_listings_count                            0
# host_total_listings_count                      0
# host_has_profile_pic                           0
# host_identity_verified                         0
# neighbourhood                                  0
# latitude                                       0
# longitude                                      0
# ...

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6049 entries, 1 to 55817
# Data columns (total 51 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   Unnamed: 0                                   6049 non-null   int64
#  1   name                                         6049 non-null   object
#  2   description                                  6049 non-null   object
#  3   neighborhood_overview                        6049 non-null   object
#  4   host_name                                    6049 non-null   object
#  5   host_since                                   6049 non-null   object
#  6   host_location                                6049 non-null   object
#  7   host_about                                   6049 non-null   object
#  8   host_response_time                           6049 non-null   object
# ...

# %% [markdown]
# # Análisis univariado

# %% [markdown]
# ## Description

# %%
table1= freq_tbl(data1["description"])
table1
# Out:
#                                             description  frequency  \
# 0     Welcome to the heart of Cefalù, a few steps fr...          6
# 1     Agriturismo Sant’Elia is situated just a few m...          6
# 2     The residence is a magical place located in a ...          6
# 3     The house is located within a historic citrus ...          5
# 4     Villa Flavia Eco B&B is located in a cove call...          5
# ...                                                 ...        ...
# 5718  The villa is an oasis of peace, situated in th...          1
# 5719  The house is fully furnished and has all the c...          1
# 5720  The house is on two floors, on the ground floo...          1
# 5721  The house overlooks a wide open space with an ...          1
# 5722  Located in Palermo 20m from the Teatro Massimo...          1
#
#       percentage  cumulative_perc
# 0       0.000992         0.000992
# 1       0.000992         0.001984
# 2       0.000992         0.002976
# ...

# %%
table1= table1.drop(['percentage','cumulative_perc'], axis=1)
table1
# Out:
#                                             description  frequency
# 0     Welcome to the heart of Cefalù, a few steps fr...          6
# 1     Agriturismo Sant’Elia is situated just a few m...          6
# 2     The residence is a magical place located in a ...          6
# 3     The house is located within a historic citrus ...          5
# 4     Villa Flavia Eco B&B is located in a cove call...          5
# ...                                                 ...        ...
# 5718  The villa is an oasis of peace, situated in th...          1
# 5719  The house is fully furnished and has all the c...          1
# 5720  The house is on two floors, on the ground floo...          1
# 5721  The house overlooks a wide open space with an ...          1
# 5722  Located in Palermo 20m from the Teatro Massimo...          1
#
# [5723 rows x 2 columns]

# %% [markdown]
# ## name

# %%
table2 = freq_tbl(data1["name"])
table2
# Out:
#                                                    name  frequency  \
# 0       [Fronte mare] Superior camera immersa nel verde          7
# 1     Residence Andrea Doria - 100m by the sea -1° F...          4
# 2        NITI - Design apartment - Castellammare/Centro          4
# 3     Hybla Major B&B- Camera matrimoniale bagno pri...          3
# 4        Borgo Marino Beach Residence - 250 mt dal mare          3
# ...                                                 ...        ...
# 5981                                   casa fondachello          1
# 5982                                    Casa al Vallone          1
# 5983                           incantevole appartamento          1
# 5984    Naxos - Panoramic studio in front of the beach.          1
# 5985                             La Giostra del Massimo          1
#
#       percentage  cumulative_perc
# 0       0.001157         0.001157
# 1       0.000661         0.001818
# 2       0.000661         0.002480
# ...

# %%
table2= table2.drop(['percentage','cumulative_perc'], axis=1)
table2
# Out:
#                                                    name  frequency
# 0       [Fronte mare] Superior camera immersa nel verde          7
# 1     Residence Andrea Doria - 100m by the sea -1° F...          4
# 2        NITI - Design apartment - Castellammare/Centro          4
# 3     Hybla Major B&B- Camera matrimoniale bagno pri...          3
# 4        Borgo Marino Beach Residence - 250 mt dal mare          3
# ...                                                 ...        ...
# 5981                                   casa fondachello          1
# 5982                                    Casa al Vallone          1
# 5983                           incantevole appartamento          1
# 5984    Naxos - Panoramic studio in front of the beach.          1
# 5985                             La Giostra del Massimo          1
#
# [5986 rows x 2 columns]

# %% [markdown]
# ## host_acceptance_rate

# %%
table3 = freq_tbl(data1["host_acceptance_rate"])
table3
# Out:
#    host_acceptance_rate  frequency  percentage  cumulative_perc
# 0                  100%       3834    0.633824         0.633824
# 1                   99%        263    0.043478         0.677302
# 2                   98%        196    0.032402         0.709704
# 3                   97%        182    0.030088         0.739792
# 4                   96%        131    0.021656         0.761448
# ..                  ...        ...         ...              ...
# 86                  23%          1    0.000165         0.999339
# 87                  14%          1    0.000165         0.999504
# 88                   4%          1    0.000165         0.999669
# 89                  27%          1    0.000165         0.999835
# 90                  37%          1    0.000165         1.000000
#
# [91 rows x 4 columns]

# %%
table3= table3.drop(['percentage','cumulative_perc'], axis=1)
table3
# Out:
#    host_acceptance_rate  frequency
# 0                  100%       3834
# 1                   99%        263
# 2                   98%        196
# 3                   97%        182
# 4                   96%        131
# ..                  ...        ...
# 86                  23%          1
# 87                  14%          1
# 88                   4%          1
# 89                  27%          1
# 90                  37%          1
#
# [91 rows x 2 columns]

# %% [markdown]
# ## host_is_superhost

# %%
table4 = freq_tbl(data1["host_acceptance_rate"])
table4
# Out:
#    host_acceptance_rate  frequency  percentage  cumulative_perc
# 0                  100%       3834    0.633824         0.633824
# 1                   99%        263    0.043478         0.677302
# 2                   98%        196    0.032402         0.709704
# 3                   97%        182    0.030088         0.739792
# 4                   96%        131    0.021656         0.761448
# ..                  ...        ...         ...              ...
# 86                  23%          1    0.000165         0.999339
# 87                  14%          1    0.000165         0.999504
# 88                   4%          1    0.000165         0.999669
# 89                  27%          1    0.000165         0.999835
# 90                  37%          1    0.000165         1.000000
#
# [91 rows x 4 columns]

# %%
table4= table4.drop(['percentage','cumulative_perc'], axis=1)
table4
# Out:
#    host_acceptance_rate  frequency
# 0                  100%       3834
# 1                   99%        263
# 2                   98%        196
# 3                   97%        182
# 4                   96%        131
# ..                  ...        ...
# 86                  23%          1
# 87                  14%          1
# 88                   4%          1
# 89                  27%          1
# 90                  37%          1
#
# [91 rows x 2 columns]

# %% [markdown]
# ## host_location

# %%
table5 = freq_tbl(data1["host_acceptance_rate"])
table5
# Out:
#    host_acceptance_rate  frequency  percentage  cumulative_perc
# 0                  100%       3834    0.633824         0.633824
# 1                   99%        263    0.043478         0.677302
# 2                   98%        196    0.032402         0.709704
# 3                   97%        182    0.030088         0.739792
# 4                   96%        131    0.021656         0.761448
# ..                  ...        ...         ...              ...
# 86                  23%          1    0.000165         0.999339
# 87                  14%          1    0.000165         0.999504
# 88                   4%          1    0.000165         0.999669
# 89                  27%          1    0.000165         0.999835
# 90                  37%          1    0.000165         1.000000
#
# [91 rows x 4 columns]

# %%
table5= table5.drop(['percentage','cumulative_perc'], axis=1)
table5
# Out:
#    host_acceptance_rate  frequency
# 0                  100%       3834
# 1                   99%        263
# 2                   98%        196
# 3                   97%        182
# 4                   96%        131
# ..                  ...        ...
# 86                  23%          1
# 87                  14%          1
# 88                   4%          1
# 89                  27%          1
# 90                  37%          1
#
# [91 rows x 2 columns]

# %% [markdown]
# ## host_since

# %%
table6 = freq_tbl(data1["host_acceptance_rate"])
table6
# Out:
#    host_acceptance_rate  frequency  percentage  cumulative_perc
# 0                  100%       3834    0.633824         0.633824
# 1                   99%        263    0.043478         0.677302
# 2                   98%        196    0.032402         0.709704
# 3                   97%        182    0.030088         0.739792
# 4                   96%        131    0.021656         0.761448
# ..                  ...        ...         ...              ...
# 86                  23%          1    0.000165         0.999339
# 87                  14%          1    0.000165         0.999504
# 88                   4%          1    0.000165         0.999669
# 89                  27%          1    0.000165         0.999835
# 90                  37%          1    0.000165         1.000000
#
# [91 rows x 4 columns]

# %%
table6= table6.drop(['percentage','cumulative_perc'], axis=1)
table6
# Out:
#    host_acceptance_rate  frequency
# 0                  100%       3834
# 1                   99%        263
# 2                   98%        196
# 3                   97%        182
# 4                   96%        131
# ..                  ...        ...
# 86                  23%          1
# 87                  14%          1
# 88                   4%          1
# 89                  27%          1
# 90                  37%          1
#
# [91 rows x 2 columns]

# %% [markdown]
# ## host_response_time

# %%
table7 = freq_tbl(data1["host_acceptance_rate"])
table7
# Out:
#    host_acceptance_rate  frequency  percentage  cumulative_perc
# 0                  100%       3834    0.633824         0.633824
# 1                   99%        263    0.043478         0.677302
# 2                   98%        196    0.032402         0.709704
# 3                   97%        182    0.030088         0.739792
# 4                   96%        131    0.021656         0.761448
# ..                  ...        ...         ...              ...
# 86                  23%          1    0.000165         0.999339
# 87                  14%          1    0.000165         0.999504
# 88                   4%          1    0.000165         0.999669
# 89                  27%          1    0.000165         0.999835
# 90                  37%          1    0.000165         1.000000
#
# [91 rows x 4 columns]

# %%
table7= table7.drop(['percentage','cumulative_perc'], axis=1)
table7
# Out:
#    host_acceptance_rate  frequency
# 0                  100%       3834
# 1                   99%        263
# 2                   98%        196
# 3                   97%        182
# 4                   96%        131
# ..                  ...        ...
# 86                  23%          1
# 87                  14%          1
# 88                   4%          1
# 89                  27%          1
# 90                  37%          1
#
# [91 rows x 2 columns]

# %% [markdown]
# ## host_response_rate

# %%
table8 = freq_tbl(data1["host_acceptance_rate"])
table8
# Out:
#    host_acceptance_rate  frequency  percentage  cumulative_perc
# 0                  100%       3834    0.633824         0.633824
# 1                   99%        263    0.043478         0.677302
# 2                   98%        196    0.032402         0.709704
# 3                   97%        182    0.030088         0.739792
# 4                   96%        131    0.021656         0.761448
# ..                  ...        ...         ...              ...
# 86                  23%          1    0.000165         0.999339
# 87                  14%          1    0.000165         0.999504
# 88                   4%          1    0.000165         0.999669
# 89                  27%          1    0.000165         0.999835
# 90                  37%          1    0.000165         1.000000
#
# [91 rows x 4 columns]

# %%
table8= table8.drop(['percentage','cumulative_perc'], axis=1)
table8
# Out:
#    host_acceptance_rate  frequency
# 0                  100%       3834
# 1                   99%        263
# 2                   98%        196
# 3                   97%        182
# 4                   96%        131
# ..                  ...        ...
# 86                  23%          1
# 87                  14%          1
# 88                   4%          1
# 89                  27%          1
# 90                  37%          1
#
# [91 rows x 2 columns]

# %% [markdown]
# ## property_type

# %%
table9 = freq_tbl(data1["host_acceptance_rate"])
table9
# Out:
#    host_acceptance_rate  frequency  percentage  cumulative_perc
# 0                  100%       3834    0.633824         0.633824
# 1                   99%        263    0.043478         0.677302
# 2                   98%        196    0.032402         0.709704
# 3                   97%        182    0.030088         0.739792
# 4                   96%        131    0.021656         0.761448
# ..                  ...        ...         ...              ...
# 86                  23%          1    0.000165         0.999339
# 87                  14%          1    0.000165         0.999504
# 88                   4%          1    0.000165         0.999669
# 89                  27%          1    0.000165         0.999835
# 90                  37%          1    0.000165         1.000000
#
# [91 rows x 4 columns]

# %%
table9= table9.drop(['percentage','cumulative_perc'], axis=1)
table9
# Out:
#    host_acceptance_rate  frequency
# 0                  100%       3834
# 1                   99%        263
# 2                   98%        196
# 3                   97%        182
# 4                   96%        131
# ..                  ...        ...
# 86                  23%          1
# 87                  14%          1
# 88                   4%          1
# 89                  27%          1
# 90                  37%          1
#
# [91 rows x 2 columns]

# %%
index9= table9.set_index('property_type')
index9
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/lk/1s80q3g16rl6xn6yqybdsx3m0000gn/T/ipykernel_8218/3713154794.py in ?()
# ----> 1 index9= table9.set_index('property_type')
#       2 index9
#
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/frame.py in ?(self, keys, drop, append, inplace, verify_integrity)
#    6118                     if not found:
#    6119                         missing.append(col)
#    6120
#    6121         if missing:
# -> 6122             raise KeyError(f"None of {missing} are in the columns")
#    6123
#    6124         if inplace:
#    6125             frame = self
#
# KeyError: "None of ['property_type'] are in the columns"

# %%
index9["frequency"].plot(kind="pie", figsize=(10,5),shadow=True, autopct="%0.1f%%")

# %% [markdown]
# ## neighbourhood

# %%
table10 = freq_tbl(data1["host_acceptance_rate"])
table10
# Out:
#    host_acceptance_rate  frequency  percentage  cumulative_perc
# 0                  100%       3834    0.633824         0.633824
# 1                   99%        263    0.043478         0.677302
# 2                   98%        196    0.032402         0.709704
# 3                   97%        182    0.030088         0.739792
# 4                   96%        131    0.021656         0.761448
# ..                  ...        ...         ...              ...
# 86                  23%          1    0.000165         0.999339
# 87                  14%          1    0.000165         0.999504
# 88                   4%          1    0.000165         0.999669
# 89                  27%          1    0.000165         0.999835
# 90                  37%          1    0.000165         1.000000
#
# [91 rows x 4 columns]

# %%
table10= table10.drop(['percentage','cumulative_perc'], axis=1)
table10
# Out:
#    host_acceptance_rate  frequency
# 0                  100%       3834
# 1                   99%        263
# 2                   98%        196
# 3                   97%        182
# 4                   96%        131
# ..                  ...        ...
# 86                  23%          1
# 87                  14%          1
# 88                   4%          1
# 89                  27%          1
# 90                  37%          1
#
# [91 rows x 2 columns]

# %% [markdown]
# # Categorizar aplicando la regla de Sturges

# %% [markdown]
# ## host_response_rate

# %%
data1["host_response_rate"].info()
n=5865
# Out:
# <class 'pandas.core.series.Series'>
# Index: 6049 entries, 1 to 55817
# Series name: host_response_rate
# Non-Null Count  Dtype
# --------------  -----
# 6049 non-null   object
# dtypes: object(1)
# memory usage: 94.5+ KB

# %%
Max=data1["host_response_rate"].max()
Min=data1["host_response_rate"].min()
Limites=[Min,Max]
Limites
# Out:
# ['0%', '99%']

# %%
ni= 1+3.32*np.log10(n)
ni
# Out:
# 13.51064981461914

# %% [markdown]
# ## host_acceptance_rate

# %%
data1["host_acceptance_rate"].info()
n=5865
# Out:
# <class 'pandas.core.series.Series'>
# Index: 6049 entries, 1 to 55817
# Series name: host_acceptance_rate
# Non-Null Count  Dtype
# --------------  -----
# 6049 non-null   object
# dtypes: object(1)
# memory usage: 94.5+ KB

# %%
Max=data1["host_acceptance_rate"].max()
Min=data1["host_acceptance_rate"].min()
Limites=[Min,Max]
Limites
# Out:
# ['0%', '99%']

# %% [markdown]
# ## host_total_listings_count

# %%
data1["host_total_listings_count"].info()
n=5865

# %%
Max=data1["host_total_listings_count"].max()
Min=data1["host_total_listings_count"].min()
Limites=[Min,Max]
Limites
# Out:
# [1.0, 1227.0]

# %% [markdown]
# ## accommodates

# %%
data1["accommodates"].info()
n=5865
# Out:
# <class 'pandas.core.series.Series'>
# Index: 6049 entries, 1 to 55817
# Series name: accommodates
# Non-Null Count  Dtype
# --------------  -----
# 6049 non-null   int64
# dtypes: int64(1)
# memory usage: 94.5 KB

# %%
Max=data1["accommodates"].max()
Min=data1["accommodates"].min()
Limites=[Min,Max]
Limites
# Out:
# [1, 16]

# %% [markdown]
# ## bathrooms

# %%
data1["bathrooms"].info()
n=5865
# Out:
# <class 'pandas.core.series.Series'>
# Index: 6049 entries, 1 to 55817
# Series name: bathrooms
# Non-Null Count  Dtype
# --------------  -----
# 6049 non-null   float64
# dtypes: float64(1)
# memory usage: 94.5 KB

# %%
Max=data1["bathrooms"].max()
Min=data1["bathrooms"].min()
Limites=[Min,Max]
Limites
# Out:
# [0.0, 12.0]

# %% [markdown]
# ## beds

# %%
data1["beds"].info()
n=5865
# Out:
# <class 'pandas.core.series.Series'>
# Index: 6049 entries, 1 to 55817
# Series name: beds
# Non-Null Count  Dtype
# --------------  -----
# 6049 non-null   float64
# dtypes: float64(1)
# memory usage: 94.5 KB

# %%
Max=data1["beds"].max()
Min=data1["beds"].min()
Limites=[Min,Max]
Limites
# Out:
# [0.0, 22.0]

# %% [markdown]
# ## price

# %%
data1["price"].info()
n=5865
# Out:
# <class 'pandas.core.series.Series'>
# Index: 6049 entries, 1 to 55817
# Series name: price
# Non-Null Count  Dtype
# --------------  -----
# 6049 non-null   object
# dtypes: object(1)
# memory usage: 94.5+ KB

# %%
Max=data1["price"].max()
Min=data1["price"].min()
Limites=[Min,Max]
Limites
# Out:
# ['$1,000.00', '$994.00']

# %% [markdown]
# ## maximum_nights

# %%
data1["maximum_nights"].info()
n=5865
# Out:
# <class 'pandas.core.series.Series'>
# Index: 6049 entries, 1 to 55817
# Series name: maximum_nights
# Non-Null Count  Dtype
# --------------  -----
# 6049 non-null   int64
# dtypes: int64(1)
# memory usage: 94.5 KB

# %%
Max=data1["maximum_nights"].max()
Min=data1["maximum_nights"].min()
Limites=[Min,Max]
Limites
# Out:
# [1, 1125]

# %% [markdown]
# ## availability_365

# %%
data1["availability_365"].info()
n=5865
# Out:
# <class 'pandas.core.series.Series'>
# Index: 6049 entries, 1 to 55817
# Series name: availability_365
# Non-Null Count  Dtype
# --------------  -----
# 6049 non-null   int64
# dtypes: int64(1)
# memory usage: 94.5 KB

# %%
Max=data1["availability_365"].max()
Min=data1["availability_365"].min()
Limites=[Min,Max]
Limites
# Out:
# [0, 365]

# %% [markdown]
# ## number_of_reviews

# %%
data1["number_of_reviews"].info()
n=5865
# Out:
# <class 'pandas.core.series.Series'>
# Index: 6049 entries, 1 to 55817
# Series name: number_of_reviews
# Non-Null Count  Dtype
# --------------  -----
# 6049 non-null   int64
# dtypes: int64(1)
# memory usage: 94.5 KB

# %%
Max=data1["number_of_reviews"].max()
Min=data1["number_of_reviews"].min()
Limites=[Min,Max]
Limites
# Out:
# [1, 845]

# %% [markdown]
# ## reviews_scores_value

# %%
data1["reviews_scores_value"].info()
n=5865

# %%
Max=data1["reviews_scores_value"].max()
Min=data1["reviews_scores_value"].min()
Limites=[Min,Max]
Limites

# %% [markdown]
# ## number_of_reviews

# %%
data1["number_of_reviews"].info()
n=5865
# Out:
# <class 'pandas.core.series.Series'>
# Index: 6049 entries, 1 to 55817
# Series name: number_of_reviews
# Non-Null Count  Dtype
# --------------  -----
# 6049 non-null   int64
# dtypes: int64(1)
# memory usage: 94.5 KB

# %%
Max=data1["number_of_reviews"].max()
Min=data1["number_of_reviews"].min()
Limites=[Min,Max]
Limites
# Out:
# [1, 845]
